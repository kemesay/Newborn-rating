# %%
# /home/name-1/AI-Agent/new-born/data/Kedir Jara CBE Statement.pdf
import pdfplumber

pdf_path = "/home/name-1/AI-Agent/new-born/data/HABESHA PETROLEUM AND (1)/ABATHNE CHANE AYLEW.pdf"

with pdfplumber.open(pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages, start=1):
        tables = page.extract_tables()
        for table_num, table in enumerate(tables, start=1):
            print(f"Page {page_num}, Table {table_num}:")
            for row in table:
                print(row)
            print("-" * 40)
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Page 1, Table 1:
# ['Information Classification', 'Number of\nRecords']
# ['Criteria used for this Enquiry', '1']
# ['Individual Identification Information', '1']
# ['Credit Report Summary', '1']
# ['Group Summary', '0']
# ['Stakeholder per Application Information', '0']
# ['Stakeholder of Financial Institution Information', '0']
# ['Credit Accounts', '37']
# ['Adverse Credit Accounts', '4']
# ['Credit Applications', '32']
# ['General Collateral Type', '0']
# ['Vehicle Collateral Type', '86']
# ['Building Collateral Type', '102']
# ['Financial Asset Collateral Type', '0']
# ['Previous Bureau Credit Report Enquiries', '137']
# ['Contact Numbers', '0']
# ['Addresses', '52']
# ['Employment and Income Information', '0']
# ['Credit Account Detail', '37']
# ['Adverse Credit Account Detail', '4']
# ----------------------------------------
# Page 2, Table 1:
# ['Criteria Type', 'Criteria Detail', 'Application Ref']
# ['TIN', '0014747784', '1428827']
# ----------------------------------------
# Page 2, Table 2:
# ['TIN Number', 'First Name', 'Fathers Name']
# ['0014747784', 'ABATHNE', 'CHANE']
# ['Grandfathers Name', 'Gender', 'Date of Birth']
# ['AYLEW', 'MALE', '1974-01-01']
# ['Nationality', None, None]
# ['ETHIOPIA', None, None]
# ----------------------------------------
# Page 2, Table 3:
# ['Cumulative Current Balance', 'Cumulative Installment', 'Income']
# ['2583919398.88', '253681428.4', '']
# ['Cumulative Arrears Amount', 'Number Of Adverse Credit Accounts', 'Worst Ever Months in Arrears']
# ['101039998.71', '4', '9']
# ['Guarantor of Other Loans', 'Member of Groups', None]
# ['11', '0', None]
# ----------------------------------------
# Page 3, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['011570154163802', None, None, '2024-03-30', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Current and within Terms', None, None, '2024-12-31', None, None, '000321100?', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['449994779.74', '55588165.5', None, None, 'Half Yearly', '464736430.05', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['3019', '100', None, None, '572755386', None, None, '45000000', None]
# ----------------------------------------
# Page 3, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Enat Bank SC', None, None, None, None, None, None]
# ['Office', None, 'ETEGE TAITU MAIN BRANCH (IB1407)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['001TTRN223620502', None, None, '2024-01-24', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Current and within Terms', None, None, '2024-12-31', None, None, '000000000000', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['258994139.27', '51421335.03', None, None, 'Quarterly', '307184078.93', None, None, '0.00']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['2192', '73', None, None, '0', None, None, '0', None]
# ----------------------------------------
# Page 4, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Enat Bank SC', None, None, None, None, None, None]
# ['Office', None, 'ETEGE TAITU MAIN BRANCH (IB1407)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['001TDOM230540001', None, None, '2024-01-16', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Current and within Terms', None, None, '2024-12-31', None, None, '000000000000', None, None]
# ['Role(s)', None, 'Spouse of Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['208940986.86', '42635982.58', None, None, 'Quarterly', '249829593.11', None, None, '0.00']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['3653', '121', None, None, '0', None, None, '0', None]
# ----------------------------------------
# Page 4, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['011510154163800', None, None, '2023-06-30', None, None, 'Overdraft', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Current and within Terms', None, None, '2024-12-31', None, None, '0320311213320??????', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['100000000', '0', None, None, 'Indefinite (For Overdraft)', '105141214.09', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['365', '12', None, None, '571755386', None, None, '300000000', None]
# ----------------------------------------
# Page 5, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['011570154163800', None, None, '2023-04-22', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2024-03-31', None, None, '021000321000', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['370000000', '0', None, None, 'Half Yearly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['4276', '142', None, None, '423502417', None, None, '423502417', None]
# ----------------------------------------
# Page 5, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Enat Bank SC', None, None, None, None, None, None]
# ['Office', None, 'ETEGE TAITU MAIN BRANCH (IB1407)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['001TIND230530001', None, None, '2023-02-22', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2024-01-31', None, None, '000000000000', None, None]
# ['Role(s)', None, 'Spouse of Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['65000000', '', None, None, 'Quarterly', '0', None, None, '0.00']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['2922', '97', None, None, '0', None, None, '0', None]
# ----------------------------------------
# Page 6, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Enat Bank SC', None, None, None, None, None, None]
# ['Office', None, 'ETEGE TAITU MAIN BRANCH (IB1407)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['OD11120290257001', None, None, '2022-12-28', None, None, 'Overdraft', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2024-05-31', None, None, '000000000000000000', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['75000000', '', None, None, 'Indefinite (For Overdraft)', '0', None, None, '0.00']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['181', '6', None, None, '0', None, None, '0', None]
# ----------------------------------------
# Page 6, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01157177926004', None, None, '2022-10-19', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Current and within Terms', None, None, '2024-12-31', None, None, '021021021021054321021021', None, None]
# ['Role(s)', None, 'Spouse of Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['46000000', '3744595.74', None, None, 'Quarterly', '34181191.33', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1826', '60', None, None, '96000000', None, None, '50000000', None]
# ----------------------------------------
# Page 7, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01157154163804', None, None, '2022-07-05', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2023-04-30', None, None, '032100000?', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['370000000', '0', None, None, 'Half Yearly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['5114', '170', None, None, '294360044', None, None, '80', None]
# ----------------------------------------
# Page 7, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01157154163803', None, None, '2022-06-30', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2024-03-31', None, None, '0320004320000021000000', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['380000000', '0', None, None, 'Half Yearly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['5479', '182', None, None, '469085566', None, None, '372343597', None]
# ----------------------------------------
# Page 8, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Hibret Bank SC', None, None, None, None, None, None]
# ['Office', None, 'GOFA (IB50)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['122DTTL200510001', None, None, '2022-06-20', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Current and within Terms', None, None, '2024-12-31', None, None, '000000099876543210000003', None, None]
# ['Role(s)', None, 'Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['15172429.72', '1230860.05', None, None, 'Quarterly', '11802651.04', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1005', '33', None, None, '15130798', None, None, '15130798', None]
# ----------------------------------------
# Page 8, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Dashen Bank SC', None, None, None, None, None, None]
# ['Office', None, 'CUSTOMER RELATIONSHIP MANAGEMENT DEP (IB2929)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['0237123557011', None, None, '2022-05-13', None, None, 'Overdraft', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2024-06-30', None, None, '0?0099579544504200000000', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['180000000', '', None, None, 'Indefinite (For Overdraft)', '0', None, None, '0.00']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['365', '12', None, None, '0', None, None, '0', None]
# ----------------------------------------
# Page 9, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01152154163804', None, None, '2022-04-18', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Current and within Terms', None, None, '2024-12-31', None, None, '021000021000021000021000', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['40846784.21', '4889409.36', None, None, 'Half Yearly', '37743411.92', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['3653', '121', None, None, '48465866', None, None, '48465866', None]
# ----------------------------------------
# Page 9, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01151177926001', None, None, '2021-05-25', None, None, 'Overdraft', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Current and within Terms', None, None, '2022-04-30', None, None, '0?8765332000', None, None]
# ['Role(s)', None, 'Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['10000000', '0', None, None, 'Indefinite (For Overdraft)', '158764.58', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['365', '12', None, None, '63993479', None, None, '63993479', None]
# ----------------------------------------
# Page 10, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01152154163801', None, None, '2021-01-04', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2022-04-19', None, None, '54321100001000', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['15000000', '0', None, None, 'Quarterly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1461', '48', None, None, '15527613', None, None, '0', None]
# ----------------------------------------
# Page 10, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Commercial Bank of Ethiopia', None, None, None, None, None, None]
# ['Office', None, 'WOLO SEFER (IB864)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['920025745', None, None, '2020-09-29', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2023-02-28', None, None, '000???00?01011??00000000', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['68011081.97', '0', None, None, 'Quarterly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1826', '60', None, None, '2754433', None, None, '0', None]
# ----------------------------------------
# Page 11, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Commercial Bank of Ethiopia', None, None, None, None, None, None]
# ['Office', None, 'WOLO SEFER (IB864)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['920025746', None, None, '2020-09-23', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2023-02-28', None, None, '000???00?01011??00000000', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['28337950.82', '0', None, None, 'Quarterly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1826', '60', None, None, '2754433', None, None, '0', None]
# ----------------------------------------
# Page 11, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Commercial Bank of Ethiopia', None, None, None, None, None, None]
# ['Office', None, 'WOLO SEFER (IB864)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['920025340', None, None, '2020-09-10', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2023-02-28', None, None, '000???00?01011??000?00?0', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['113319672.13', '0', None, None, 'Quarterly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1824', '60', None, None, '0', None, None, '3', None]
# ----------------------------------------
# Page 12, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Bunna Bank SC', None, None, None, None, None, None]
# ['Office', None, 'GERJI MEBERAT HAIL BRANCH (IB2273)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['1889101000002', None, None, '2020-07-20', None, None, 'Overdraft', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2022-03-29', None, None, '0000000000000000000??', None, None]
# ['Role(s)', None, 'Spouse of Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['3000000', '0', None, None, 'Indefinite (For Overdraft)', '0', None, None, '0.00']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['364', '12', None, None, '7619344', None, None, '80', None]
# ----------------------------------------
# Page 12, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01152154163803', None, None, '2020-06-27', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2022-04-19', None, None, '543211000076543543210', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['38414068.21', '0', None, None, 'Quarterly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1285', '42', None, None, '63993479', None, None, '48465866', None]
# ----------------------------------------
# Page 13, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01157154163802', None, None, '2020-06-27', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2021-05-31', None, None, '099876543210', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['2061194.82', '0', None, None, 'Quarterly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['392', '13', None, None, '15527613', None, None, '0', None]
# ----------------------------------------
# Page 13, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01157177926002', None, None, '2020-06-27', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2022-04-19', None, None, '987654321213322103210', None, None]
# ['Role(s)', None, 'Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['17740099.44', '0', None, None, 'Monthly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1364', '45', None, None, '63993499', None, None, '63993499', None]
# ----------------------------------------
# Page 14, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Bunna Bank SC', None, None, None, None, None, None]
# ['Office', None, 'GERJI MEBERAT HAIL BRANCH (IB2273)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['1889003000033', None, None, '2020-05-15', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2023-05-06', None, None, '000000000000000000000000', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['20000000', '0', None, None, 'Half Yearly', '0', None, None, '0.00']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1095', '36', None, None, '0', None, None, '0', None]
# ----------------------------------------
# Page 14, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Dashen Bank SC', None, None, None, None, None, None]
# ['Office', None, 'CUSTOMER RELATIONSHIP MANAGEMENT DEP (IB2929)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['237DMTS2010400WH', None, None, '2020-04-13', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Current and within Terms', None, None, '2024-12-31', None, None, '00?000000099989068421620', None, None]
# ['Role(s)', None, 'Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['139587086.37', '12000000', None, None, 'Quarterly', '137311248.22', None, None, '0.00']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['3287', '109', None, None, '96064042', None, None, '101046042', None]
# ----------------------------------------
# Page 15, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01151177926000', None, None, '2019-06-12', None, None, 'Overdraft', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2022-04-19', None, None, '02200000000066666?0?????', None, None]
# ['Role(s)', None, 'Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['101499.45', '0', None, None, 'Indefinite (For Overdraft)', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['365', '12', None, None, '0', None, None, '15527613', None]
# ----------------------------------------
# Page 15, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Hibret Bank SC', None, None, None, None, None, None]
# ['Office', None, 'GOFA (IB50)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['122DTTL190520001', None, None, '2019-02-21', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Early Settlement', None, None, '2020-03-31', None, None, '00324354321000', None, None]
# ['Role(s)', None, 'Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['25000000', '0', None, None, 'Quarterly', '0', None, None, '0.00']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1460', '48', None, None, '11630798', None, None, '11630798', None]
# ----------------------------------------
# Page 16, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Hibret Bank SC', None, None, None, None, None, None]
# ['Office', None, 'GOFA (IB50)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['122DTTL182820001', None, None, '2018-10-09', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Early Settlement', None, None, '2019-02-28', None, None, '01000', None, None]
# ['Role(s)', None, 'Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['25000000', '0', None, None, 'Quarterly', '0', None, None, '0.00']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1460', '48', None, None, '10730798', None, None, '9230798', None]
# ----------------------------------------
# Page 16, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01157154163800', None, None, '2018-07-24', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2020-07-31', None, None, '0?64321?????????????????', None, None]
# ['Role(s)', None, 'Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['3200000', '0', None, None, 'Quarterly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1095', '36', None, None, '15527613', None, None, '0', None]
# ----------------------------------------
# Page 17, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01151153099000', None, None, '2018-07-05', None, None, 'Overdraft', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Current and within Terms', None, None, '2022-04-30', None, None, '0?5432110000000000000000', None, None]
# ['Role(s)', None, 'Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['20000000', '0', None, None, 'Indefinite (For Overdraft)', '276612.72', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['3', '0', None, None, '0', None, None, '15527613', None]
# ----------------------------------------
# Page 17, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Bunna Bank SC', None, None, None, None, None, None]
# ['Office', None, 'GERJI MEBERAT HAIL BRANCH (IB2273)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['1889003000028', None, None, '2018-06-25', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2021-06-29', None, None, '000000000000000000000000', None, None]
# ['Role(s)', None, 'Spouse of Borrower', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['10000000', '0', None, None, 'Quarterly', '0', None, None, '0.00']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1095', '36', None, None, '10461203', None, None, '0', None]
# ----------------------------------------
# Page 18, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01152153099000', None, None, '2018-06-14', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2022-04-19', None, None, '654321021001021000021100', None, None]
# ['Role(s)', None, 'Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['14000000', '0', None, None, 'Quarterly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1826', '60', None, None, '4000000', None, None, '15527613', None]
# ----------------------------------------
# Page 18, Table 2:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Awash International Bank SC', None, None, None, None, None, None]
# ['Office', None, 'WELLO SEFER (IB2917)', None, None, None, None, None, None]
# ['Account No', None, None, 'Date Opened', None, None, 'Credit Type', None, None]
# ['01157153099000', None, None, '2018-06-12', None, None, 'Installment Credit', None, None]
# ['Status', None, None, 'Status Date', None, None, 'Payment Profile String', None, None]
# ['Settled in Full - Normal', None, None, '2022-04-19', None, None, '876543211100322100010200', None, None]
# ['Role(s)', None, 'Guarantor', None, None, None, None, None, None]
# ['Financial Information', None, None, None, None, None, None, None, None]
# ['Credit Amount', 'Installment', None, None, 'Installment Frequency', 'Current Balance', None, None, 'Balance Overdue']
# ['16000000', '0', None, None, 'Monthly', '0', None, None, '0']
# ['Term (No of Days)', 'Term (No of Months)', None, None, 'Secured by Collateral Total', None, None, 'Secured by Guarantor Total', None]
# ['1826', '60', None, None, '0', None, None, '63993479', None]
# ----------------------------------------
# Page 19, Table 1:
# ['Account Detail', None, None, None, None, None, None, None, None]
# ['Institution', None, 'Bunna Bank SC', None, None, None, None, None, None]
# ...
# Page 158, Table 1:
# ['Field', 'Data']
# ['Institution', 'Enat Bank SC']
# ['Office', 'ETEGE TAITU MAIN BRANCH']
# ['Account Number', '11120287452001']
# ['Role in Credit Account', 'Guarantor']
# ['Number of Borrowers linked to Credit Account', '1']
# ['Number of Guarantors linked to Credit Account', '2']
# ['Secured by Guarantor Total', '2']
# ['Supported by General Collateral Type Total Market Value', '0']
# ['Supported by Vehicle Collateral Type Total Market Value', '0']
# ['Supported by Building Collateral Type Total Market Value', '0']
# ['Supported by Financial Asset Collateral Type Total Market Value', '0']
# ['Group Identification Number', 'NONE']
# ['Approved Amount', '169165184.01']
# ['Date Account Opened', '2024-06-25']
# ['Credit Type', 'Installment Credit']
# ['Product Type', 'Student Loan']
# ['Opening Balance / Credit Limit', '169165184.01']
# ['Opening Balance Indicator', 'Opening Balance']
# ['Reporting Date', '2024-12-31']
# ['Maturity Date', '2030-06-25']
# ['Payment Due Date', '2030-06-25']
# ['Repayment Frequency', 'Quarterly']
# ['Number of Installments', '1']
# ['Installment Amount', '13502409.87']
# ['Current Balance Amount', '178135573.42']
# ['Current Balance Indicator', 'Debit']
# ['Last Payment Date', '']
# ['Credit Account Status', 'Outstanding and in Arrears']
# ['Last Status Change Date', '2024-12-31']
# ['Credit Account Risk Classification', 'SUBSTANDARD']
# ['Credit Account Arrears Date', '2024-11-28']
# ['Number of Days in Arrears', '']
# ['Balance Overdue', '']
# ['Outstanding Balance of Arrears Account', '']
# ['Restructured Credit', 'Restructured']
# ['Restructured Credit Reference Number', '1.11203E+13']
# ['Industry Sector', 'Domestic Trade And Service']
# ['Industry Sub-Sector', 'Domestic Trade']
# ['Credit Account Closure Date', '']
# ['Credit Account Closure Reason', '']
# ['Client Consent', '']
# ['Loan Term (Days)', '']
# ['Loan Term (Months)', '6']
# ['Account is part of Export Guarantee', '']
# ----------------------------------------
# Page 159, Table 1:
# ['Field', 'Data']
# ['Institution', 'Awash International Bank SC']
# ['Office', 'WELLO SEFER']
# ['Account Number', '011570154163801']
# ['Role in Credit Account', 'Borrower']
# ['Number of Borrowers linked to Credit Account', '1']
# ['Number of Guarantors linked to Credit Account', '3']
# ['Secured by Guarantor Total', '300000000']
# ['Supported by General Collateral Type Total Market Value', '0']
# ['Supported by Vehicle Collateral Type Total Market Value', '7622900000']
# ['Supported by Building Collateral Type Total Market Value', '520355386']
# ['Supported by Financial Asset Collateral Type Total Market Value', '0']
# ['Group Identification Number', 'NONE']
# ['Approved Amount', '430454070.42']
# ['Date Account Opened', '2024-03-30']
# ['Credit Type', 'Installment Credit']
# ['Product Type', 'Student Loan']
# ['Opening Balance / Credit Limit', '430454070.42']
# ['Opening Balance Indicator', 'Opening Balance']
# ['Reporting Date', '2024-12-31']
# ['Maturity Date', '2037-03-30']
# ['Payment Due Date', '2037-03-30']
# ['Repayment Frequency', 'Half Yearly']
# ['Number of Installments', '23']
# ['Installment Amount', '48468670.27']
# ['Current Balance Amount', '448979650.41']
# ['Current Balance Indicator', 'Debit']
# ['Last Payment Date', '2024-12-31']
# ['Credit Account Status', 'Outstanding and in Arrears']
# ['Last Status Change Date', '2024-12-31']
# ['Credit Account Risk Classification', 'PASS']
# ['Credit Account Arrears Date', '2024-12-30']
# ['Number of Days in Arrears', '1']
# ['Balance Overdue', '49828167.72']
# ['Outstanding Balance of Arrears Account', '']
# ['Restructured Credit', 'Normal']
# ['Restructured Credit Reference Number', '']
# ['Industry Sector', 'Domestic Trade And Service']
# ['Industry Sub-Sector', 'Domestic Trade']
# ['Credit Account Closure Date', '']
# ['Credit Account Closure Reason', '']
# ['Client Consent', 'No']
# ['Loan Term (Days)', '']
# ['Loan Term (Months)', '158']
# ['Account is part of Export Guarantee', 'No']
# ----------------------------------------
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Page 160, Table 1:
# ['Field', 'Data']
# ['Institution', 'Dashen Bank SC']
# ['Office', 'CUSTOMER RELATIONSHIP']
# ['Account Number', '237TRST221330001']
# ['Role in Credit Account', 'Borrower']
# ['Number of Borrowers linked to Credit Account', '1']
# ['Number of Guarantors linked to Credit Account', '0']
# ['Secured by Guarantor Total', '0']
# ['Supported by General Collateral Type Total Market Value', '0']
# ['Supported by Vehicle Collateral Type Total Market Value', '0']
# ['Supported by Building Collateral Type Total Market Value', '0']
# ['Supported by Financial Asset Collateral Type Total Market Value', '0']
# ['Group Identification Number', 'NONE']
# ['Approved Amount', '149583333.34']
# ['Date Account Opened', '2022-05-13']
# ['Credit Type', 'Installment Credit']
# ['Product Type', 'Student Loan']
# ['Opening Balance / Credit Limit', '149583333.34']
# ['Opening Balance Indicator', 'Opening Balance']
# ['Reporting Date', '2024-12-31']
# ['Maturity Date', '2027-05-13']
# ['Payment Due Date', '2025-03-13']
# ['Repayment Frequency', 'Quarterly']
# ['Number of Installments', '20']
# ['Installment Amount', '10200000']
# ['Current Balance Amount', '141962904.69']
# ['Current Balance Indicator', 'Debit']
# ['Last Payment Date', '']
# ['Credit Account Status', 'Outstanding and in Arrears']
# ['Last Status Change Date', '2024-12-31']
# ['Credit Account Risk Classification', 'SPECIAL MENTION']
# ['Credit Account Arrears Date', '2024-11-13']
# ['Number of Days in Arrears', '48']
# ['Balance Overdue', '10200000']
# ['Outstanding Balance of Arrears Account', '']
# ['Restructured Credit', 'Normal']
# ['Restructured Credit Reference Number', '']
# ['Industry Sector', 'Domestic Trade And Service']
# ['Industry Sub-Sector', 'Transport Service']
# ['Credit Account Closure Date', '']
# ['Credit Account Closure Reason', '']
# ['Client Consent', '']
# ['Loan Term (Days)', '']
# ['Loan Term (Months)', '60']
# ['Account is part of Export Guarantee', 'No']
# ----------------------------------------
# Page 161, Table 1:
# ['Field', 'Data']
# ['Institution', 'Nib International Bank SC']
# ['Office', 'BISRATEGEBRIEL']
# ['Account Number', 'PER7000025422835']
# ['Role in Credit Account', 'Borrower']
# ['Number of Borrowers linked to Credit Account', '1']
# ['Number of Guarantors linked to Credit Account', '1']
# ['Secured by Guarantor Total', '250000000']
# ['Supported by General Collateral Type Total Market Value', '0']
# ['Supported by Vehicle Collateral Type Total Market Value', '0']
# ['Supported by Building Collateral Type Total Market Value', '250000000']
# ['Supported by Financial Asset Collateral Type Total Market Value', '0']
# ['Group Identification Number', 'NONE']
# ['Approved Amount', '400000000']
# ['Date Account Opened', '2021-07-28']
# ['Credit Type', 'Installment Credit']
# ['Product Type', 'Student Loan']
# ['Opening Balance / Credit Limit', '400000000']
# ['Opening Balance Indicator', 'Opening Balance']
# ['Reporting Date', '2023-06-30']
# ['Maturity Date', '2033-01-28']
# ['Payment Due Date', '2023-02-21']
# ['Repayment Frequency', 'Quarterly']
# ['Number of Installments', '40']
# ['Installment Amount', '10000000']
# ['Current Balance Amount', '466476074.37']
# ['Current Balance Indicator', 'Debit']
# ['Last Payment Date', '']
# ['Credit Account Status', 'Outstanding and in Arrears']
# ['Last Status Change Date', '2023-06-30']
# ['Credit Account Risk Classification', 'SPECIAL MENTION']
# ['Credit Account Arrears Date', '2021-09-25']
# ['Number of Days in Arrears', '63']
# ['Balance Overdue', '41011830.99']
# ['Outstanding Balance of Arrears Account', '']
# ['Restructured Credit', 'Normal']
# ['Restructured Credit Reference Number', '']
# ['Industry Sector', 'Housing and Construction']
# ['Industry Sub-Sector', 'Commercial Building']
# ['Credit Account Closure Date', '']
# ['Credit Account Closure Reason', '']
# ['Client Consent', '']
# ['Loan Term (Days)', '']
# ['Loan Term (Months)', '121']
# ['Account is part of Export Guarantee', 'No']
# ----------------------------------------
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
